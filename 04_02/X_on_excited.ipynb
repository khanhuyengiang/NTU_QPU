# %%
# Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from qibolab import create_platform, ExecutionParameters, AveragingMode, AcquisitionType
from qibolab.pulses import Pulse, ReadoutPulse, PulseSequence, Drag
from tqdm import tqdm

# Setting execution parameters
opts = ExecutionParameters(
    nshots=1000,  # Number of shots
    relaxation_time=200e3,  # Qubit relaxation time in ns
    acquisition_type=AcquisitionType.INTEGRATION,  # Type of acquisition
    averaging_mode=AveragingMode.SEQUENTIAL  # Averaging mode
)

# Creating platform and connecting
platform = create_platform("icarusq_rd_sq_a11")
platform.connect()

# Creating readout pulses for qubits 6 and 7
q6_ro = platform.create_qubit_readout_pulse(5, 0)
q7_ro = platform.create_qubit_readout_pulse(6, 0)

# Creating pi pulses for qubits 6 and 7
q6_pi_pulse = platform.create_RX_pulse(qubit=5, start=5)
q7_pi_pulse = platform.create_RX_pulse(qubit=6, start=5)
q7_drive_pulse = platform.create_qubit_drive_pulse(qubit=6, start=5, duration=5)

######################################################
# Q6 CRTL Q7 TARGET

# Creating control pulse
CR_pulse = q7_pi_pulse.copy()
CR_pulse.channel = q6_pi_pulse.channel

# Setting up pulse lengths for Rabi experiment
rabi_pulse_length = np.arange(0, 1000, 20)

# Initializing arrays for results
crtl_gnd_results = np.zeros(len(rabi_pulse_length))
crtl_exc_results = np.zeros(len(rabi_pulse_length))

# Setting up pulse lengths for Rabi experiment
rabi_pulse_length_part_1 = np.arange(0, 160, 20)
rabi_pulse_length_part_2 = np.arange(160, 1000, 20) + q7_pi_pulse.duration
inverting_pulse_length = np.arange(160, 160+q7_pi_pulse.duration,20)
inverting_pulse = q7_pi_pulse.copy()
inverting_pulse.start = 160

# Creating pulse sequence for ground state
ps = PulseSequence(*[CR_pulse, q7_ro])

# Performing Rabi experiment for ground state
for idx, t in enumerate(tqdm(rabi_pulse_length_part_1)):
    CR_pulse.duration = t
    q7_ro.start = CR_pulse.finish
    crtl_gnd_results[idx] = platform.execute_pulse_sequence(ps, opts)[q7_ro.serial].magnitude

# Creating pulse sequence for ground state
ps = PulseSequence(*[CR_pulse, q7_drive_pulse, q7_ro])
CR_pulse.duration = 160
for idx, t in enumerate(tqdm(inverting_pulse_length)):
    q7_drive_pulse.duration = t
    q7_drive_pulse.start = CR_pulse.finish
    q7_ro.start = q7_pi_pulse.finish
    crtl_gnd_results[idx+len(rabi_pulse_length_part_1)] = platform.execute_pulse_sequence(ps, opts)[q7_ro.serial].magnitude

# Creating pulse sequence for ground state
CR_pulse_2 = CR_pulse.copy()
ps = PulseSequence(*[CR_pulse, q7_pi_pulse, CR_pulse_2, q7_ro])

for idx, t in enumerate(tqdm(rabi_pulse_length_part_2)):
    q7_pi_pulse.start = CR_pulse.finish
    CR_pulse_2.start = q7_pi_pulse.finish
    CR_pulse_2.duration = t
    q7_ro.start = CR_pulse_2.finish
    crtl_gnd_results[idx+len(inverting_pulse_length)] = platform.execute_pulse_sequence(ps, opts)[q7_ro.serial].magnitude

# Plotting results
plt.scatter(rabi_pulse_length, crtl_gnd_results, color="blue")
#plt.scatter(rabi_pulse_length, crtl_exc_results, color="orange")
plt.savefig('rabi.png')  # Saving plot as image file
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 17
#       9 opts = ExecutionParameters(
#      10     nshots=1000,  # Number of shots
#      11     relaxation_time=200e3,  # Qubit relaxation time in ns
#      12     acquisition_type=AcquisitionType.INTEGRATION,  # Type of acquisition
#      13     averaging_mode=AveragingMode.SEQUENTIAL  # Averaging mode
#      14 )
#      16 # Creating platform and connecting
# ---> 17 platform = create_platform("icarusq_rd_sq_a11")
#      18 platform.connect()
#      20 # Creating readout pulses for qubits 6 and 7
#
# File ~/Documents/paul/qibolab/src/qibolab/__init__.py:55, in create_platform(name, runcard)
#      52 spec.loader.exec_module(module)
#      54 if runcard is None:
# ---> 55     return module.create()
#      56 return module.create(runcard)
#
# File /qibolab_platforms_nqch/icarusq_rd_sq_a11.py:47, in create(runcard)
#      46 def create(runcard=RUNCARD):
# ---> 47     controller = RFSOC_RO("board2", ADDRESS,
#      48                            dac_sampling_rate=5898.24,
#      49                            adc_sampling_rate=1966.08,
#      50                            delay_samples_offset_dac=0,
#      51                            delay_samples_offset_adc=11)
#      52     attenuator = MCAttenuator("ro_att", "192.168.0.10:100")
#      53     attenuator.attenuation = 20
#
# File ~/Documents/paul/qibolab/src/qibolab/instruments/icarusqfpga.py:234, in RFSOC_RO.__init__(self, name, address, dac_sampling_rate, adc_sampling_rate, delay_samples_offset_dac, delay_samples_offset_adc, analog_settings)
#     224 def __init__(
#     225     self,
#     226     name,
#    (...)
#     232     analog_settings: List["dict[str, int]"] = [],
#     233 ):
# --> 234     super().__init__(
#     235         name,
#     236         address,
#     237         dac_sampling_rate=dac_sampling_rate,
#     238         adc_sampling_rate=adc_sampling_rate,
#     239         delay_samples_offset_dac=delay_samples_offset_dac,
#     240         delay_samples_offset_adc=delay_samples_offset_adc,
#     241         analog_settings=analog_settings,
#     242     )
#     244     self.adcs_to_read: List[int] = None
#     246     self.device.init_qunit()
#
# File ~/Documents/paul/qibolab/src/qibolab/instruments/icarusqfpga.py:46, in RFSOC.__init__(self, name, address, port, dac_sampling_rate, adc_sampling_rate, delay_samples_offset_dac, delay_samples_offset_adc, analog_settings)
#      34 def __init__(
#      35     self,
#      36     name,
#    (...)
#      43     analog_settings: List["dict[str, int]"] = [],
#      44 ):
#      45     super().__init__(name, address)
# ---> 46     self.device = IcarusQRFSoC(address, port)
#      48     self.device.dac_sampling_rate = dac_sampling_rate
#      49     self.device.adc_sampling_rate = adc_sampling_rate
#
# File ~/Documents/paul/rfsoc-driver/src/icarusq_rfsoc_driver/rfsoc_driver.py:41, in IcarusQRFSoC.__init__(self, address, port)
#      38 self.num_qunit = 10
#      40 # Test connection
# ---> 41 self.get_server_version()
#      42 self._dac_sampling_rate = self.get_dac_sampling_rate()
#      43 self._adc_sampling_rate = self.get_adc_sampling_rate()
#
# File ~/Documents/paul/rfsoc-driver/src/icarusq_rfsoc_driver/rfsoc_driver.py:552, in IcarusQRFSoC.get_server_version(self)
#     550 encoding = ENCODING[COMMAND_GET_VERSION]
#     551 self.sock.encode_and_send_bytes(COMMAND_GET_VERSION, encoding)
# --> 552 version_str = self.sock.recv(50).decode("utf-8")
#     554 return version_str
#
# KeyboardInterrupt:
