# %%
import numpy as np
list_q1 = np.load('x_expects_q1.npy')
list_q2 = np.load('x_expects_q2.npy')
list_base_q1 = np.load('baseline_expects_q1.npy')
list_base_q2 = np.load('baseline_expects_q2.npy')
times = np.load('x_pulse_times.npy')
Q1=2
Q2=4

# %%
def simple_rescaling(array, reference_array):
    max_value = max(reference_array)
    min_value = min(reference_array)
    average = (max_value + min_value)/2
    diff = (max_value - min_value)/2
    return (array-average)/diff

# %% [markdown]
# x_expectation = simple_rescaling(list,list)
# baseline_q1 = simple_rescaling(list_base_q1,list)
# baseline_q2 = simple_rescaling(list_base_q2,list)

# %%
import matplotlib.pyplot as plt
plt.rcParams["legend.loc"] = 'lower center'
plt.rcParams["legend.fancybox"] = True
plt.rcParams['text.usetex'] = False
plt.rcParams["font.family"] = 'serif'
import numpy as np
plt.plot(times,list_base_q1,label = f'Q{Q1} Without pulsing')
plt.plot(times,list_base_q2,label = f'Q{Q2} Without pulsing')
plt.plot(times,list_q1, label = f'Q{Q1} During X pulse')
plt.plot(times,list_q2, label = f'Q{Q2} During X pulse')
plt.xlabel('Time t (ns)')
plt.ylabel(f'Average expectation values of the shots\n(unknown axis scale, max = {np.round(max(list_q2))})')
plt.title(f'Average expectation values during X pulse on Q{Q2}, amplitude = 0.2')
plt.axvspan(5, 178, alpha=0.1, color='red', label = r'One $X(\pi/2)$ pulse')
plt.legend(bbox_to_anchor=(0.5, -0.4),shadow=True, ncol=3)
plt.tight_layout()
plt.savefig('X_expectation.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 9
#       7 plt.plot(times,list_base_q1,label = f'Q{Q1} Without pulsing')
#       8 plt.plot(times,list_base_q2,label = f'Q{Q2} Without pulsing')
# ----> 9 plt.plot(times,list_q1, label = f'Q{Q1} During X pulse')
#      10 plt.plot(times,list_q2, label = f'Q{Q2} During X pulse')
#      11 plt.xlabel('Time t (ns)')
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:3575, in plot(scalex, scaley, data, *args, **kwargs)
#    3567 @_copy_docstring_and_deprecators(Axes.plot)
#    3568 def plot(
#    3569     *args: float | ArrayLike | str,
#    (...)
#    3573     **kwargs,
#    3574 ) -> list[Line2D]:
# -> 3575     return gca().plot(
#    3576         *args,
#    3577         scalex=scalex,
#    3578         scaley=scaley,
#    3579         **({"data": data} if data is not None else {}),
# ...

# %%
finish_t = 250
idle_duration = 200

times_test = np.load('times.npy')
list_test = np.load('Hahn_echo.npy')

plt.plot(times_test, list_test)
plt.xlabel('Time t (ns)')
plt.ylabel(f'Average expectation values of the shots\n(unknown axis scale, max = {np.round(max(list_q2))})')
plt.axvspan(5+idle_duration,5+finish_t+idle_duration, alpha=0.1, color='red', label = r'$X(\pi)$ pulse')
plt.axvspan(5+2*idle_duration+finish_t,5+2*idle_duration+2*finish_t, alpha=0.1, color='red')
plt.axvspan(5,5+idle_duration, alpha=0.1, color='green', label = 'Idle evolution')
plt.axvspan(5+finish_t+idle_duration,5+2*idle_duration+finish_t, alpha=0.1, color='green')
plt.legend(bbox_to_anchor=(0.5, -0.25),shadow=True, ncol=2)
plt.title('Attempts to invert always on interaction\nusing Hahn echo with initial state 01')
# Out:
# Text(0.5, 1.0, 'Attempts to invert always on interaction\nusing Hahn echo with initial state 01')
