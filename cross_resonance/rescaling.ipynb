# %%
import numpy as np  
import matplotlib.pyplot as plt

# %%
for TGT,CRTL in [(0,2),(0,3),(1,2),(1,3),(2,0),(2,1),(2,3),(3,0),(3,1),(3,2)]:
    gnd = np.load(f"./ro_change_data/crtl_0_cr_{CRTL}{TGT}.npy")
    exc = np.load(f"./ro_change_data/crtl_1_cr_{CRTL}{TGT}.npy")
# Out:
# 0 2
# 0 3
# 1 2
# 1 3
# 2 0
# 2 1
# 2 3
# 3 0
# 3 1
# 3 2

# %%
gnd = np.load(f"./data/crtl_0_cr_{CRTL}{TGT}.npy")
exc = np.load(f"./data/crtl_1_cr_{CRTL}{TGT}.npy")
